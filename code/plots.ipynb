# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("../data/demographic_data.xlsx")

print(df)
# Out:
#         Sub ID   Age Gender     Handedness               Vision
# 0     sub34_AB  22.0  Female  Right handed  Corrected to normal
# 1     sub23_AB  21.0  Female  Right handed               Normal
# 2     sub46_NB  20.0  Female  Right handed  Corrected to normal
# 3     sub72_NB  28.0    Male  Right handed  Corrected to normal
# 4    sub150_NB  27.0    Male  Right handed               Normal
# ..         ...   ...     ...           ...                  ...
# 180  sub158_NB  24.0    Male  Right handed  Corrected to normal
# 181   sub31_AB  24.0    Male  Right handed               Normal
# 182  sub177_NB  26.0    Male  Right handed               Normal
# 183  sub106_AB  23.0    Male  Right handed  Corrected to normal
# 184  sub171_NB  23.0    Male  Right handed               Normal
#
# [185 rows x 5 columns]
