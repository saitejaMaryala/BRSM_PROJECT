# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cleaned_summary = "../cleaned_data/cleaned_summary.csv"

data = pd.read_csv(cleaned_summary)

#print len of the data
len(data)
# Out:
# 171
